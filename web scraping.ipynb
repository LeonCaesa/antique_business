# %%
import requests
import json
import shutil

# %%
response = requests.get("https://www.dpm.org.cn/collection/enamels.html&ved=2ahUKEwissvDC4pTrAhXDLH0KHUQbAPMQFjAOegQIBxAB&usg=AOvVaw2UFxpKJrBq-C_W9I4SaaH0&cshid=1597204890023")



print(json.loads(response.text))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[88], line 6
#       3 url = 'https://www.dpm.org.cn/searchs/enamels/category_id/100/dbg/0/p/1.html'
#       4 response = requests.get(url)
# ----> 6 print(json.loads(response.text))
#
# File ~/miniconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...

# %%
import re



regex = """<a target="_blank" href="/collection/enamel/.*?" id="(.*?)">\n(.*?)<div class="box">\n.*?\n.*?<img src="(.*?)">\n.*?</div>\n.*?</div>\n.*?</a>\n.*?</td>\n.*?<td>.*?\n(.*?)</td>.*?<td>\n(.*?)</td>"""
                                                
pat = re.compile(regex)

# %%
# Out:
# 'https://img.dpm.org.cn/Uploads//Uploads/Picture/dc/368.jpg'

# %%
pic_root = 'https://img.dpm.org.cn/'


for i in range(1, 14):
    url = 'https://www.dpm.org.cn/searchs/enamels/category_id/100/dbg/0/p/'+str(i) + '.html'
    response = requests.get(url)

    
    
    for each_row in pat.findall(test_string):
        id, name, pic, dynasty, type = each_row
        name = name.strip(' ')
        dynasty = dynasty.strip(' ')
        type = type.strip(' ')
    
    
        
        pic_response = requests.get(pic_root + pic, stream=True)
        with open('./data/' + str(id) + dynasty + '_True.jpg', 'wb') as out_file:
            #shutil.copyfileobj(pic_response.raw, out_file)
            out_file.write(pic_response.content)

# %%
pic_root + pic
# Out:
# 'https://img.dpm.org.cn/Uploads/Uploads/Picture/dc/368.jpg'

# %%
'https://img.dpm.org.cn/Uploads/Picture/dc/342.jpg'
# Out:
# 'https://img.dpm.org.cn/Uploads/Picture/dc/342.jpg'

# %%
item_url = 'https://www.dpm.org.cn/collection/enamel/234076'

# %%
test_string = """
<tbody>
            <tr>

                <th width="45%">文物名称</th>
                <th width="25%">
                    时代                </th><th width="25%">
                    分类                </th>            </tr>
                        <tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/234654" id="234654">
                            掐丝珐琅缠枝莲纹鼎式炉                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/342.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/229352" id="229352">
                            景泰款掐丝珐琅缠枝莲纹兽耳三环尊                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/12444.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/229317" id="229317">
                            景泰款掐丝珐琅缠枝莲纹龙耳瓶                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/10542.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/229066" id="229066">
                            掐丝珐琅缠枝莲纹冲耳三足炉                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/10548.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/228922" id="228922">
                            掐丝珐琅缠枝莲纹藏草瓶                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/3632.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/228132" id="228132">
                            掐丝珐琅缠枝莲纹象耳炉                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/1940.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                元                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/229354" id="229354">
                            掐丝珐琅葡萄纹绳耳炉                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/12447.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明早期                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/229318" id="229318">
                            掐丝珐琅缠枝莲纹球式香熏                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/10691.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明早期                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/228131" id="228131">
                            掐丝珐琅花朵纹玉壶春瓶                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/1939.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明早期                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/228130" id="228130">
                            景泰款掐丝珐琅缠枝莲纹梅瓶                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/1937.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明早期                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/234467" id="234467">
                            宣德款掐丝珐琅缠枝花卉纹盏托                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/374.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明宣德                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr><tr>
                    <td>
                        <a target="_blank" href="/collection/enamel/234466" id="234466">
                            景泰款掐丝珐琅缠枝莲纹尊                            <div class="box">
                                <div class="img">
                                    <img src="/Uploads/Picture/dc/368.jpg">
                                </div>
                            </div>
                        </a>
                    </td>
                                        <td>
                                                明宣德                                            </td>                                                <td>
                                                掐丝珐琅                                            </td>                </tr>            </tbody>

"""

# %%
print(response.text)
# Out:
# <!doctype html>
# <html>
# <head>
#     <script>
# 	if (window.location.host.indexOf("dpm.org.cn") != -1) {
# 		if (window.location.protocol == 'http:') window.location.href = 'https:' + window.location.href.substring(window.location.protocol.length);
# 	}
# </script>
#     <!-- 静态化时间 2024-09-25 10:01:23 -->    <meta charset="utf-8">
#     <meta http-equiv="Cache-Control" content="no-cache">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="renderer" content="webkit">
#     <meta name="author" content="www.fractal-technology.com">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" />
#
#     <title>珐琅 - 故宫博物院</title>
#     <meta name="keywords" content="故宫博物院,故宫,故宫官网,故宫博物院官网" />
#     <meta name="description" content="故宫博物院成立于1925年10月10日，是以明清两代皇宫和宫廷旧藏文物为基础建立起来的大型综合性古代艺术博物馆，是世界文化遗产地、全国重点文物保护单位和爱国主义教育示范基地。" />
# ...
